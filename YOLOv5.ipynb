# %% [markdown]
# <a href="https://colab.research.google.com/github/pawara101/computer-vision-algos/blob/main/YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Env Setup, Data dowload and library setup

# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.12 MiB | 21.49 MiB/s, done.
# Resolving deltas: 100% (11858/11858), done.

# %% [markdown]
# ## Download annotated data

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pnKvew4NHz0nXfi7EqXH")
project = rf.workspace("brad-dwyer").project("oxford-pets")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Oxford-Pets-2 in yolov5pytorch:: 100%|██████████| 7372/7372 [00:00<00:00, 8255.99it/s]

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
! pip install -r requirements.txt  # install
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 59.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pnKvew4NHz0nXfi7EqXH")
project = rf.workspace("brad-dwyer").project("oxford-pets")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Oxford-Pets-2 in yolov5pytorch:: 100%|██████████| 7372/7372 [00:00<00:00, 7925.07it/s]

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/Image-processing/data-cats-dogs'

# %%
# !cp /content/data/train/cat.1000[0-9].jpg '/content/drive/MyDrive/Colab Notebooks/Image-processing/data-cats-dogs/'

# %%
# !cp /content/data/train/dog.1000[0-9].jpg '/content/drive/MyDrive/Colab Notebooks/Image-processing/data-cats-dogs/'

# %%
# !ls '/content/data/train' > '/content/data/train.txt'

# %%
# %cd /content/
# Out:
# /content

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
from IPython.display import Image
Image(filename='/content/Oxford-Pets-2/train/images/Abyssinian_103_jpg.rf.d6f56d3f97d62e11ab1c43036e98161f.jpg', width=600)

# %%
# !ls  "/content/Oxford-Pets-2/train/images/" | head -10
# Out:
# Abyssinian_100_jpg.rf.ac857e7c2457ab89dd6edacb21e6fb7c.jpg
# Abyssinian_102_jpg.rf.e89f4c1898ba0c2bf4ff8b24f47a5f4c.jpg
# Abyssinian_103_jpg.rf.d6f56d3f97d62e11ab1c43036e98161f.jpg
# Abyssinian_104_jpg.rf.b9b83b115d919cae9c0cd249048855d2.jpg
# Abyssinian_107_jpg.rf.5a3e1331a1aba7847b3d02d4a3235ea4.jpg
# Abyssinian_108_jpg.rf.d30f63f4403f3540221ec3ab58a948d0.jpg
# Abyssinian_109_jpg.rf.687f0c760f6ef790ea030c0fcc3b14de.jpg
# Abyssinian_10_jpg.rf.4ea1ee7cc1c302cedfddac6b7b8433e0.jpg
# Abyssinian_110_jpg.rf.034902ccec7888913c2ca80336e70dab.jpg
# Abyssinian_111_jpg.rf.9e166839baadff6b365fe76e54185357.jpg

# %%
# !ls  "/content/Oxford-Pets-2/train/labels" | head -10
# Out:
# Abyssinian_100_jpg.rf.ac857e7c2457ab89dd6edacb21e6fb7c.txt
# Abyssinian_102_jpg.rf.e89f4c1898ba0c2bf4ff8b24f47a5f4c.txt
# Abyssinian_103_jpg.rf.d6f56d3f97d62e11ab1c43036e98161f.txt
# Abyssinian_104_jpg.rf.b9b83b115d919cae9c0cd249048855d2.txt
# Abyssinian_107_jpg.rf.5a3e1331a1aba7847b3d02d4a3235ea4.txt
# Abyssinian_108_jpg.rf.d30f63f4403f3540221ec3ab58a948d0.txt
# Abyssinian_109_jpg.rf.687f0c760f6ef790ea030c0fcc3b14de.txt
# Abyssinian_10_jpg.rf.4ea1ee7cc1c302cedfddac6b7b8433e0.txt
# Abyssinian_110_jpg.rf.034902ccec7888913c2ca80336e70dab.txt
# Abyssinian_111_jpg.rf.9e166839baadff6b365fe76e54185357.txt

# %%
# !python train.py --img 640 --epochs 3 --data "/content/Oxford-Pets-2/data.yaml" --weights yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-20 10:17:57.088016: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740046677.401476    2830 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
Image(filename='/content/yolov5/runs/train/exp/F1_curve.png', width=600)

# %%
Image(filename='/content/yolov5/runs/train/exp/R_curve.png', width=600)

# %%
Image(filename='/content/yolov5/runs/train/exp/PR_curve.png', width=600)

# %%
Image(filename='/content/yolov5/runs/train/exp/confusion_matrix.png', width=600)

# %%
Image(filename='/content/yolov5/runs/train/exp/train_batch0.jpg', width=600)

# %%
Image(filename='/content/yolov5/runs/train/exp/val_batch1_pred.jpg', width=600)

# %%
Image(filename='/content/yolov5/runs/train/exp/val_batch1_labels.jpg', width=600)

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp/weights/best.pt' --img 640 --conf 0.4 --source '/content/yolov5/Oxford-Pets-2/test/images/Birman_137_jpg.rf.6b400b7db04673f857543e60c9988871.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/Oxford-Pets-2/test/images/Birman_137_jpg.rf.6b400b7db04673f857543e60c9988871.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/Oxford-Pets-2/test/images/Birman_137_jpg.rf.6b400b7db04673f857543e60c9988871.jpg: 448x640 1 cat, 236.2ms
# Speed: 6.7ms pre-process, 236.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
Image(filename='/content/yolov5/runs/detect/exp/Birman_137_jpg.rf.6b400b7db04673f857543e60c9988871.jpg', width=600)

# %%
test_data_list=[]
import os
test_data_path = "/content/Oxford-Pets-2/test/images"
dir_list = os.listdir(test_data_path)

# %%
len(dir_list)
# Out:
# 368

# %%
dir_list[0]
# Out:
# 'chihuahua_17_jpg.rf.bc9ce34829cc903772311214c761f4fa.jpg'

# %%
for i in range(3):  # No need for (0, 3), just use (3)
    image_path = f"/content/Oxford-Pets-2/test/images/{dir_list[i]}"
    # !python detect.py --weights '/content/yolov5/runs/train/exp/weights/best.pt' --img 640 --conf 0.4 --source {image_path}
    print("Done")
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Oxford-Pets-2/test/images/chihuahua_17_jpg.rf.bc9ce34829cc903772311214c761f4fa.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Oxford-Pets-2/test/images/chihuahua_17_jpg.rf.bc9ce34829cc903772311214c761f4fa.jpg: 384x640 1 dog, 168.4ms
# Speed: 1.6ms pre-process, 168.4ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
Image(filename='/content/yolov5/runs/detect/exp11/chihuahua_17_jpg.rf.bc9ce34829cc903772311214c761f4fa.jpg', width=600)

# %%
Image(filename='/content/yolov5/runs/detect/exp12/pomeranian_11_jpg.rf.57a452f5e14ed59aed630cb64296f84a.jpg', width=600)

# %%
Image(filename='/content/yolov5/runs/detect/exp13/english_cocker_spaniel_17_jpg.rf.9ce3eb26114231a007bd64c18e5ee84c.jpg', width=600)

# %%
eval_list = []
path = "/content/yolov5/runs/train/exp/"
dir_files_eval = os.listdir(path)
dir_files_eval
# Out:
# ['val_batch0_pred.jpg',
#  'val_batch2_pred.jpg',
#  'train_batch1.jpg',
#  'val_batch1_pred.jpg',
#  'F1_curve.png',
#  'PR_curve.png',
#  'val_batch2_labels.jpg',
#  'val_batch0_labels.jpg',
#  'results.csv',
#  'P_curve.png',
#  'train_batch2.jpg',
#  'events.out.tfevents.1740046713.0cb842666008.2830.0',
#  'confusion_matrix.png',
#  'R_curve.png',
#  'weights',
#  'labels_correlogram.jpg',
#  'opt.yaml',
#  'hyp.yaml',
#  'train_batch0.jpg',
#  'val_batch1_labels.jpg',
#  'labels.jpg',
#  'results.png']

# %%
import re
for i in range(0,len(dir_files_eval)):
  if re.search(r"\.(jpg|png)$",dir_files_eval[i],re.IGNORECASE):
    # Image(filename=f'/content/yolov5/runs/train/exp/{dir_files_eval[i]}', width=600)
    print(dir_files_eval[i])
# Out:
# val_batch0_pred.jpg
# val_batch2_pred.jpg
# train_batch1.jpg
# val_batch1_pred.jpg
# F1_curve.png
# PR_curve.png
# val_batch2_labels.jpg
# val_batch0_labels.jpg
# P_curve.png
# train_batch2.jpg
# confusion_matrix.png
# R_curve.png
# labels_correlogram.jpg
# train_batch0.jpg
# val_batch1_labels.jpg
# labels.jpg
# results.png

# %%
Image(filename=f'/content/yolov5/runs/train/exp/val_batch0_pred.jpg', width=600)

# %%
#Torch Imports

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, Dataset
import torchvision
from torchvision import datasets, models, transforms

#Basic Imports

import numpy as np #For Linear Algebra
import pandas as pd #For Data Frame Making
import matplotlib.pyplot as plt #For Visualization And Plot Making
from sklearn.model_selection import train_test_split #For Data Spliting
import zipfile #For Zip Opening
import os
from tqdm import tqdm
import shutil
from PIL import Image

# %%
data_transforms = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

# %%
class TrainCustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.cat_images = [os.path.join(root_dir, i) for i in os.listdir(root_dir) if i.split(".")[0] == "cat"]
        self.dog_images = [os.path.join(root_dir, i) for i in os.listdir(root_dir) if i.split(".")[0] == "dog"]

        self.images = self.cat_images + self.dog_images
        self.labels = [0] * len(self.cat_images) + [1] * len(self.dog_images)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        with Image.open(img_path) as img:
            image = img.convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
## Load dataset
ROOT_DIR = "/content/data/train"
dataset = TrainCustomDataset(root_dir=ROOT_DIR, transform=data_transforms)

# %%
dataset[24000][1]
# Out:
# 1

# %%
## Split data
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# %%
## Train Loop Parameters
BATCH_SIZE = 64
EPOCHS = 10
LEARNING_RATE = 0.00001

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
## Load pretrained model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
