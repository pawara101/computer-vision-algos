# %% [markdown]
# <a href="https://colab.research.google.com/github/pawara101/computer-vision-algos/blob/main/RCNN_Aeroplane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Document [Faster RCNN](https://towardsdatascience.com/airplanes-detection-for-satellite-using-faster-rcnn-d307d58353f1/)
# - Authour's [code](https://github.com/ShubhankarRawat/Airplane-Detection-for-Satellites/tree/master)

# %%
## Dataset
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aceofspades914/cgi-planes-in-satellite-imagery-w-bboxes")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.30G/1.30G [00:21<00:00, 64.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/aceofspades914/cgi-planes-in-satellite-imagery-w-bboxes/versions/1

# %%
# %ls /root/.cache/kagglehub/datasets/aceofspades914/cgi-planes-in-satellite-imagery-w-bboxes/versions/1
# Out:
# test/  test_labels.csv  train/  training/  train_labels.csv

# %%
# %mkdir /content/data/
# %cp -r /root/.cache/kagglehub/datasets/aceofspades914/cgi-planes-in-satellite-imagery-w-bboxes/versions/1/* /content/data/

# %%
import os,glob
DATA_PATH = "/content/data"
all_files_trainDir = os.listdir(DATA_PATH+"/train")
all_img_files_train = glob.glob(DATA_PATH+"/train/*.png")
all_xml_files_train = glob.glob(DATA_PATH+"/train/*.xml")

all_files_testDir = os.listdir(DATA_PATH+"/test")
all_img_files_test = glob.glob(DATA_PATH+"/test/*.png")
all_xml_files_test = glob.glob(DATA_PATH+"/test/*.xml")

# %%
# !git clone https://github.com/ShubhankarRawat/Airplane-Detection-for-Satellites.git
# Out:
# Cloning into 'Airplane-Detection-for-Satellites'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 84 (delta 0), reused 0 (delta 0), pack-reused 81 (from 1)
# Receiving objects: 100% (84/84), 2.02 MiB | 21.74 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
len(all_img_files_train)
# Out:
# 400

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image
img = mpimg.imread('/content/data/train/img1.png')
# Display the image
imgplot = plt.imshow(img)
plt.show()

# %%
# %cat '/content/data/train/img1.xml'
# Out:
#     <annotation>
#         <folder>Python Fun</folder>
#         <filename>img1.png</filename>
#         <path>C:\Users\rober\Documents\Python Fun\plane.png</path>
#         <source>
#             <database>Unknown</database>
#         </source>
#         <size>
#             <width>1000</width>
#             <height>700</height>
#             <depth>3</depth>
#         </size>
#         <segmented>0</segmented>
#
#         <object>
#             <name>plane</name>
#             <pose>Unspecified</pose>
#             <truncated>0</truncated>
#             <difficult>0</difficult>
#             <bndbox>
#                 <xmin>410</xmin>
#                 <ymin>356</ymin>
#                 <xmax>469</xmax>
#                 <ymax>419</ymax>
#             </bndbox>
#         </object>
#         <object>
#             <name>plane</name>
#             <pose>Unspecified</pose>
#             <truncated>0</truncated>
#             <difficult>0</difficult>
#             <bndbox>
# ...
